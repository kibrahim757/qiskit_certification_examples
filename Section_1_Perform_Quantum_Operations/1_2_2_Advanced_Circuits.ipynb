# %% [markdown]
# # Task 1.2: Apply Quantum Operations (Part 2)
# ## Objective 1b: Advanced & Algorithmic Circuit Library
#
# **Overview:**
# This notebook covers high-level algorithmic components used in Variational Algorithms, Machine Learning, and Optimization.
# *   **Advanced Arithmetic:** Comparators, Reciprocals.
# *   **N-Local Circuits:** EfficientSU2, RealAmplitudes (Ansatzes).
# *   **Oracles & Templates:** Tools for specific algorithms like Grover's.

# %% [markdown]
# ### **Advanced Building Blocks: Other Arithmetic Functions**
#
# Beyond the fundamental operations of addition, multiplication, and functional rotations, Qiskit's circuit library is equipped with a variety of other specialized arithmetic components. These gates and circuits are essential building blocks for constructing sophisticated quantum algorithms, particularly in the fields of optimization, finance, and solving systems of linear equations.
#
# As with other generalized operations, Qiskit provides these functions in two forms: abstract `Gate` representations, which describe the mathematical operation for the transpiler to optimize, and concrete `QuantumCircuit` implementations, which are ready-to-use algorithmic blocks.
#
# ---
#
# #### **The Quantum Reciprocal: A Key to Solving Equations**
#
# One of the most powerful applications of quantum computing is its potential to solve large systems of linear equations, a task central to countless problems in science and engineering. The famous **HHL algorithm** (named after Harrow, Hassidim, and Lloyd) achieves this by, in part, calculating the reciprocal of numbers.
#
# *   **`ExactReciprocalGate`**: This abstract `Gate` represents the function `f(x) = 1/x`. It is designed to compute the exact reciprocal for an integer `x`. This operation is non-trivial to implement on a quantum computer and is a critical subroutine for algorithms that need to perform division or matrix inversion.
#
# *   **`ExactReciprocal`**: This is the concrete `QuantumCircuit` implementation of the exact reciprocal algorithm. It provides a specific circuit that performs this calculation, which can be directly composed with other parts of a larger quantum program.
#
# ---
#
# #### **Quantum Decision-Making: The Integer Comparator**
#
# Many algorithms, both classical and quantum, rely on conditional logic—the ability to perform different actions based on whether a certain condition is met. A fundamental building block for this is a comparator.
#
# *   **`IntegerComparatorGate`**: This `Gate` performs a comparison between the integer value encoded in a quantum register and a given classical integer. It can be configured to check for conditions like "greater than or equal to" (`>=`) or "less than" (`<`). The result of the comparison is typically flipped on a separate "result" qubit, which can then be used as a control for subsequent operations, effectively creating a quantum "if" statement.
#
# *   **`IntegerComparator`**: The `QuantumCircuit` that provides a specific implementation of the integer comparison logic. This is an essential tool for algorithms in quantum finance (e.g., comparing a stock price to a strike price) and optimization.
#
# ---
#
# #### **Optimization's Core: Evaluating Quadratic Forms**
#
# Many of the most challenging and valuable optimization problems—from logistics and scheduling to financial modeling and drug discovery—can be mathematically formulated as finding the minimum value of a **quadratic form**. These are often expressed as **QUBO (Quadratic Unconstrained Binary Optimization)** problems.
#
# *   **`QuadraticFormGate`**: This abstract `Gate` is designed to evaluate a quadratic function on binary variables that are encoded in quantum registers. The function is of the general form `Q(x) = xᵀAx + bᵀx`, where `x` is a vector of binary variables (represented by qubits), `A` is a matrix, and `b` is a vector. This gate encodes the value of `Q(x)` into the phase of the quantum state, making it a powerful tool for use with algorithms like Quantum Phase Estimation to find the optimal solution.
#
# *   **`QuadraticForm`**: The concrete `QuantumCircuit` implementation that builds the circuit for evaluating the quadratic form.
#
# ---
#
# #### **Calculating Value: The Weighted Sum**
#
# While a standard adder computes `a + b`, many applications require the calculation of a **weighted sum**, such as `Σ(wᵢ * xᵢ)`, where each input variable `xᵢ` is multiplied by a specific weight `wᵢ`. This is fundamental to tasks like calculating the value of a financial portfolio or the output of a linear machine learning model.
#
# *   **`WeightedSumGate`**: This abstract `Gate` represents the operation of computing the weighted sum of several quantum registers. You provide the list of weights, and the gate defines the mathematical transformation that adds these weighted values together.
#
# *   **`WeightedAdder`**: This is the corresponding `QuantumCircuit` that implements the weighted sum operation. It takes multiple quantum registers as input and adds their values, scaled by the provided weights, into an output register.

# %%
# Example

# %% [markdown]
# ### Particular Quantum Circuits

# %% [markdown]
# The following gate derive ```Gate```
#
# * fourier_checking -->	Fourier checking circuit.
# * hidden_linear_function -->	Circuit to solve the hidden linear function problem.
# * iqp -->	Instantaneous quantum polynomial time (IQP) circuit.
# * random_iqp -->	A random instantaneous quantum polynomial time (IQP) circuit.
# * quantum_volume -->	A quantum volume model circuit.
# * phase_estimation -->	Phase Estimation circuit.
# * grover_operator -->	Construct the Grover operator.
# * unitary_overlap -->	Circuit that returns the overlap between two unitaries U2†U1.
# * GraphStateGate -->	A gate representing a graph state.
# * PauliEvolutionGate -->	Time-evolution of an operator consisting of Paulis.
# * HamiltonianGate -->	Class for representing evolution by a Hamiltonian operator as a gate.
#
# The following gates derive ```QuantumCircuit```
#
# * FourierChecking -->	Fourier checking circuit.
# * GraphState -->	Circuit to prepare a graph state.
# * HiddenLinearFunction -->	Circuit to solve the hidden linear function problem.
# * IQP -->	Instantaneous quantum polynomial (IQP) circuit.
# * QuantumVolume -->	A quantum volume model circuit.
# * PhaseEstimation -->	Phase Estimation circuit.
# * GroverOperator -->	The Grover operator.
# * UnitaryOverlap -->	Circuit that returns the overlap between two unitaries U2†U1​.

# %%
from qiskit.circuit.library import IQP

#iqp=IQP(interactions)
#qc.compose(iqp).draw('mpl')

# %% [markdown]
# ### N Local Circuits

# %% [markdown]
# return a parameterized ```QuantumCircuit``` to use as ansatz in variational quantum circuits

# %% [markdown]
# The following gates derive ```QuantumCircuit```
#
# * n_local -->	Construct an n-local variational circuit.
# * efficient_su2 -->	The hardware-efficient SU(2)SU(2) 2-local circuit.
# * real_amplitudes -->	Construct a real-amplitudes 2-local circuit.
# * pauli_two_design -->	Construct a Pauli 2-design ansatz.
# * excitation_preserving -->	The heuristic excitation-preserving wave function ansatz.
# * qaoa_ansatz -->	A generalized QAOA quantum circuit with a support of custom initial states and mixers.
# * hamiltonian_variational_ansatz -->	Construct a Hamiltonian variational ansatz.
# * evolved_operator_ansatz -->	Construct an ansatz out of operator evolutions.
#
# The following gates derive ```BlueprintCircuit``` which wrap the circuits into a block and allow for inplace mutations of the circuits
#
# * NLocal -->	The n-local circuit class.
# * TwoLocal -->	The two-local circuit.
# * PauliTwoDesign -->	The Pauli Two-Design ansatz.
# * RealAmplitudes -->	The real-amplitudes 2-local circuit.
# * EfficientSU2 -->	The hardware efficient SU(2) 2-local circuit.
# * EvolvedOperatorAnsatz -->	The evolved operator ansatz.
# * ExcitationPreserving -->	The heuristic excitation-preserving wave function ansatz.
# * QAOAAnsatz -->	A generalized QAOA quantum circuit with a support of custom initial states and mixers.

# %%
from qiskit.circuit.library import real_amplitudes
 
ansatz = real_amplitudes(5, entanglement="pairwise")

from qiskit.circuit.library import zz_feature_map
num_qubits = 5
qc = zz_feature_map(num_qubits)
qc.barrier()
qc.compose(ansatz, inplace=True)
 
qc.draw("mpl")

# %% [markdown]
# ### Data Encoding Ciruicts

# %% [markdown]
# return a parameterized QuantumCircuit to use in data encoding circuits in variational quantum algorithms
#
# The following gates derive ```QuantumCircuit```
#
#
# * pauli_feature_map --> The Pauli expansion circuit.
# * z_feature_map --> The first order Pauli Z-evolution circuit.
# * zz_feature_map --> Second-order Pauli-Z evolution circuit.
#
# The following gates derive ```BlueprintCircuit``` which wrap the circuits into a block and allow for inplace mutations of the circuits
#
# * PauliFeatureMap -->	The Pauli Expansion circuit.
# * ZFeatureMap -->	The first order Pauli Z-evolution circuit.
# * ZZFeatureMap -->	Second-order Pauli-Z evolution circuit.

# %%
# Example

# %% [markdown]
# ### Data Prepration Circuits
#
# * StatePrepration --> Complex amplitude state preparation.
# * Initialize --> Complex amplitude initialization.

# %%
# Example

# %% [markdown]
# ### Oracles
#
# black-box operations on quantum circuits
#
# ```Gate``` Version Gates
#
# * PhaseOracleGate --> implements a phase oracle.
# * BitFlipOracleGate --> implements a bitflip oracle
#
# ```QuantumCircuit``` version Gate
#
# * PhaseOracle --> phase oracle

# %%
# Example

# %% [markdown]
# ### Template Circuits
#
# They are used in circuit optimization
#
# * NCT (Not-CNot-toffoli) --> XGate, CXGate, CCXGate
#     * template_nct_2a_1
#     * template_nct_2a_2
#     * template_nct_2a_3
#     * template_nct_4a_1
#     * template_nct_4a_2
#     * template_nct_4a_3
#     * template_nct_4b_1
#     * template_nct_4b_2
#     * template_nct_5a_1
#     * template_nct_5a_2
#     * template_nct_5a_3
#     * template_nct_5a_4
#     * template_nct_6a_1
#     * template_nct_6a_2
#     * template_nct_6a_3
#     * template_nct_6a_4
#     * template_nct_6b_1
#     * template_nct_6b_2
#     * template_nct_6c_1
#     * template_nct_7a_1
#     * template_nct_7b_1
#     * template_nct_7c_1
#     * template_nct_7d_1
#     * template_nct_7e_1
#     * template_nct_9a_1
#     * template_nct_9c_1
#     * template_nct_9c_2
#     * template_nct_9c_3
#     * template_nct_9c_4
#     * template_nct_9c_5
#     * template_nct_9c_6
#     * template_nct_9c_7
#     * template_nct_9c_8
#     * template_nct_9c_9
#     * template_nct_9c_10
#     * template_nct_9c_11
#     * template_nct_9c_12
#     * template_nct_9d_1
#     * template_nct_9d_2
#     * template_nct_9d_3
#     * template_nct_9d_4
#     * template_nct_9d_5
#     * template_nct_9d_6
#     * template_nct_9d_7
#     * template_nct_9d_8
#     * template_nct_9d_9
#     * template_nct_9d_10
# * Clifford --> Cllifford Gates
#     * clifford_2_1
#     * clifford_2_2
#     * clifford_2_3
#     * clifford_2_4
#     * clifford_3_1
#     * clifford_4_1
#     * clifford_4_2
#     * clifford_4_3
#     * clifford_4_4
#     * clifford_5_1
#     * clifford_6_1
#     * clifford_6_2
#     * clifford_6_3
#     * clifford_6_4
#     * clifford_6_5
#     * clifford_8_1
#     * clifford_8_2
#     * clifford_8_3
# * RZX --> RZXGate
#     * rzx_yz
#     * rzx_xz
#     * rzx_cy
#     * rzx_zz1
#     * rzx_zz2
#     * rzx_zz3

# %%
from qiskit.circuit.library.templates import template_nct_4b_1
from qiskit.quantum_info import Operator
import numpy as np
 
template = template_nct_4b_1()
 
identity = np.identity(2 ** len(template.qubits), dtype=complex)
data = Operator(template).data
np.allclose(data, identity)  # True, template_nct_4b_1 is the identity
# Out:
# True
